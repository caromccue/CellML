# %%
from math import sqrt

import numpy as np

import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
postsize = ['2.5', '5', '10']
x = np.arange(len(postsize))
y = [129.92199284910012, 402.67630494136284, 272.0987040509081]
errory = [18.398248001488348, 154.960398698617, 108.53733280127639]

fig, ax = plt.subplots()
ax.bar(x, y, yerr = errory, align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('Cell Area ($\mu m^2$)')
ax.set_xticks(x)
ax.set_xticklabels(postsize)
ax.set_xlabel('Post Diameter ($\mu m$)')
ax.set_title('Total Cell Area on Micropost Surfaces')


# Save the figure and show
plt.tight_layout()
plt.savefig('Cell Area on Microposts')
plt.show()

# %%
postsize = ['2.5', '5', '10']
x = np.arange(len(postsize))
y = [0.3901451698318888, 0.5232841984548809, 0.42303863611057535]
errory = [0.15935916985142778, 0.16732473126204037, 0.14619294186855988]

fig, ax = plt.subplots()
ax.bar(x, y, yerr = errory, align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('Spreading Factor')
ax.set_xticks(x)
ax.set_xticklabels(postsize)
ax.set_xlabel('Post Diameter ($\mu m$)')
ax.set_title('Spreading Factor of Cells on Micropost Surfaces')


# Save the figure and show
plt.tight_layout()
plt.savefig('Cell Spreading Factor')
plt.show()

# %%
postsize = ['2.5', '5', '10']
x = np.arange(len(postsize))
y = [0.45846207062427446, 0.4060382863592566, 0.31836661592496035]
errory = [0.11677681627205388, 0.09654578507433212, 0.14069388652334486]

fig, ax = plt.subplots()
ax.bar(x, y, yerr = errory, align='center', alpha=0.5, ecolor='black', capsize=10)
ax.set_ylabel('Cell Circularity')
ax.set_xticks(x)
ax.set_xticklabels(postsize)
ax.set_xlabel('Post Diameter ($\mu m$)')
ax.set_title('Circularity of Cells on Micropost Surfaces')


# Save the figure and show
plt.tight_layout()
plt.savefig('Cell Circularity')
plt.show()
